# %%
import pandas as pd

import matplotlib.pyplot as plt

# Plotting settings
plt.style.use('ggplot')
plt.rcParams['font.sans-serif'] = ['Arial Unicode MS', 'SimHei']
plt.rcParams['axes.unicode_minus'] = False

# Configuration parameters
FILE_PATH = '../../data/raw/train.txt'
MAX_ROWS = 1000

# Define column names
cols = ['label'] + [f'I{i}' for i in range(1, 14)] + [f'C{i}' for i in range(1, 27)]
num_features = [f'I{i}' for i in range(1, 14)]

try:
    # Read data
    data = pd.read_csv(
        FILE_PATH,
        sep='\t',
        header=None,
        names=cols,
        nrows=MAX_ROWS
    )

    print(f"Data dimensions: {data.shape}")
    display(data.head().style.background_gradient(subset=num_features, cmap='Blues'))

    # Calculate statistics for each column
    stats = []
    total_memory = data.memory_usage(deep=True).sum()
    total_rows = len(data)  # Total number of samples for calculating missing ratio

    for col in data.columns:
        # Feature type
        dtype = str(data[col].dtype)

        # Calculate cardinality (number of distinct values, excluding missing values)
        cardinality = data[col].nunique(dropna=True)

        # Memory usage (in bytes)
        memory_usage = data[col].memory_usage(deep=True)

        # Memory usage ratio
        memory_ratio = (memory_usage / total_memory) * 100

        # Missing value statistics
        missing_count = data[col].isna().sum()  # Number of missing values
        missing_ratio = (missing_count / total_rows) * 100  # Missing value ratio (%)

        stats.append({
            'Feature': col,
            'Type': dtype,
            'Cardinality': cardinality,
            'Missing Count': missing_count,
            'Missing Ratio(%)': round(missing_ratio, 2),
            'Memory Usage(MB)': round(memory_usage / 1024 / 1024, 2),
            'Memory Ratio(%)': round(memory_ratio, 2)
        })

    # Convert to DataFrame and display
    stats_df = pd.DataFrame(stats)

    # Sort by missing ratio in descending order (can modify sorting field as needed)
    stats_df = stats_df.sort_values(by='Missing Ratio(%)', ascending=False)

    # Display results
    print("\nFeature Statistics (including missing value analysis):")
    display(stats_df.style
            .bar(subset=['Missing Ratio(%)'], color='salmon')  # Mark missing ratio with red bars
            .bar(subset=['Memory Ratio(%)'], color='lightblue')
            .background_gradient(subset=['Cardinality'], cmap='viridis'))

except FileNotFoundError:
    print(f"Error: File {FILE_PATH} not found, please check if the path is correct")
except Exception as e:
    print(f"An error occurred during data processing: {str(e)}")
# Out:
# Data dimensions: (1000, 40)
# <style type="text/css">
# #T_38f0d_row0_col1, #T_38f0d_row0_col2, #T_38f0d_row0_col4, #T_38f0d_row0_col10, #T_38f0d_row0_col12, #T_38f0d_row1_col2, #T_38f0d_row1_col10, #T_38f0d_row1_col12, #T_38f0d_row2_col2, #T_38f0d_row2_col3, #T_38f0d_row2_col10, #T_38f0d_row2_col12, #T_38f0d_row3_col7, #T_38f0d_row3_col8, #T_38f0d_row3_col9, #T_38f0d_row3_col10, #T_38f0d_row3_col11, #T_38f0d_row3_col12, #T_38f0d_row4_col2, #T_38f0d_row4_col4, #T_38f0d_row4_col5, #T_38f0d_row4_col6, #T_38f0d_row4_col8, #T_38f0d_row4_col9, #T_38f0d_row4_col10, #T_38f0d_row4_col12, #T_38f0d_row4_col13 {
#   background-color: #f7fbff;
#   color: #000000;
# }
# #T_38f0d_row0_col3, #T_38f0d_row1_col6 {
#   background-color: #e5eff9;
#   color: #000000;
# }
# #T_38f0d_row0_col5 {
#   background-color: #b2d2e8;
#   color: #000000;
# }
# #T_38f0d_row0_col6, #T_38f0d_row0_col13 {
#   background-color: #eef5fc;
#   color: #000000;
# }
# #T_38f0d_row0_col7, #T_38f0d_row0_col8, #T_38f0d_row1_col3, #T_38f0d_row1_col8, #T_38f0d_row2_col4, #T_38f0d_row2_col6, #T_38f0d_row2_col8, #T_38f0d_row2_col9, #T_38f0d_row2_col11, #T_38f0d_row2_col13, #T_38f0d_row3_col2, #T_38f0d_row3_col5, #T_38f0d_row4_col1 {
#   background-color: #08306b;
#   color: #f1f1f1;
# }
# #T_38f0d_row0_col9 {
#   background-color: #2373b6;
#   color: #f1f1f1;
# }
# #T_38f0d_row0_col11 {
#   background-color: #3787c0;
#   color: #f1f1f1;
# }
# #T_38f0d_row1_col1, #T_38f0d_row2_col1 {
#   background-color: #6aaed6;
#   color: #f1f1f1;
# }
# #T_38f0d_row1_col4 {
#   background-color: #e9f2fa;
#   color: #000000;
# }
# #T_38f0d_row1_col5 {
#   background-color: #f3f8fe;
#   color: #000000;
# }
# #T_38f0d_row1_col7 {
#   background-color: #dceaf6;
#   color: #000000;
# }
# #T_38f0d_row1_col9 {
#   background-color: #f4f9fe;
#   color: #000000;
# }
# #T_38f0d_row1_col11, #T_38f0d_row4_col11 {
#   background-color: #abd0e6;
#   color: #000000;
# }
# #T_38f0d_row1_col13 {
#   background-color: #e6f0f9;
#   color: #000000;
# }
# #T_38f0d_row2_col5 {
#   background-color: #d5e5f4;
#   color: #000000;
# }
# #T_38f0d_row2_col7 {
#   background-color: #c1d9ed;
#   color: #000000;
# }
# #T_38f0d_row3_col1, #T_38f0d_row3_col3, #T_38f0d_row3_col4, #T_38f0d_row3_col6, #T_38f0d_row3_col13, #T_38f0d_row4_col3 {
#   background-color: #000000;
#   color: #f1f1f1;
# }
# #T_38f0d_row4_col7 {
#   background-color: #d0e1f2;
#   color: #000000;
# }
# </style>
# <table id="T_38f0d">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_38f0d_level0_col0" class="col_heading level0 col0" >label</th>
#       <th id="T_38f0d_level0_col1" class="col_heading level0 col1" >I1</th>
#       <th id="T_38f0d_level0_col2" class="col_heading level0 col2" >I2</th>
#       <th id="T_38f0d_level0_col3" class="col_heading level0 col3" >I3</th>
#       <th id="T_38f0d_level0_col4" class="col_heading level0 col4" >I4</th>
#       <th id="T_38f0d_level0_col5" class="col_heading level0 col5" >I5</th>
#       <th id="T_38f0d_level0_col6" class="col_heading level0 col6" >I6</th>
#       <th id="T_38f0d_level0_col7" class="col_heading level0 col7" >I7</th>
#       <th id="T_38f0d_level0_col8" class="col_heading level0 col8" >I8</th>
#       <th id="T_38f0d_level0_col9" class="col_heading level0 col9" >I9</th>
#       <th id="T_38f0d_level0_col10" class="col_heading level0 col10" >I10</th>
#       <th id="T_38f0d_level0_col11" class="col_heading level0 col11" >I11</th>
#       <th id="T_38f0d_level0_col12" class="col_heading level0 col12" >I12</th>
#       <th id="T_38f0d_level0_col13" class="col_heading level0 col13" >I13</th>
#       <th id="T_38f0d_level0_col14" class="col_heading level0 col14" >C1</th>
#       <th id="T_38f0d_level0_col15" class="col_heading level0 col15" >C2</th>
#       <th id="T_38f0d_level0_col16" class="col_heading level0 col16" >C3</th>
#       <th id="T_38f0d_level0_col17" class="col_heading level0 col17" >C4</th>
#       <th id="T_38f0d_level0_col18" class="col_heading level0 col18" >C5</th>
#       <th id="T_38f0d_level0_col19" class="col_heading level0 col19" >C6</th>
#       <th id="T_38f0d_level0_col20" class="col_heading level0 col20" >C7</th>
#       <th id="T_38f0d_level0_col21" class="col_heading level0 col21" >C8</th>
#       <th id="T_38f0d_level0_col22" class="col_heading level0 col22" >C9</th>
#       <th id="T_38f0d_level0_col23" class="col_heading level0 col23" >C10</th>
#       <th id="T_38f0d_level0_col24" class="col_heading level0 col24" >C11</th>
#       <th id="T_38f0d_level0_col25" class="col_heading level0 col25" >C12</th>
#       <th id="T_38f0d_level0_col26" class="col_heading level0 col26" >C13</th>
#       <th id="T_38f0d_level0_col27" class="col_heading level0 col27" >C14</th>
#       <th id="T_38f0d_level0_col28" class="col_heading level0 col28" >C15</th>
#       <th id="T_38f0d_level0_col29" class="col_heading level0 col29" >C16</th>
#       <th id="T_38f0d_level0_col30" class="col_heading level0 col30" >C17</th>
#       <th id="T_38f0d_level0_col31" class="col_heading level0 col31" >C18</th>
#       <th id="T_38f0d_level0_col32" class="col_heading level0 col32" >C19</th>
#       <th id="T_38f0d_level0_col33" class="col_heading level0 col33" >C20</th>
#       <th id="T_38f0d_level0_col34" class="col_heading level0 col34" >C21</th>
#       <th id="T_38f0d_level0_col35" class="col_heading level0 col35" >C22</th>
#       <th id="T_38f0d_level0_col36" class="col_heading level0 col36" >C23</th>
#       <th id="T_38f0d_level0_col37" class="col_heading level0 col37" >C24</th>
#       <th id="T_38f0d_level0_col38" class="col_heading level0 col38" >C25</th>
#       <th id="T_38f0d_level0_col39" class="col_heading level0 col39" >C26</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_38f0d_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_38f0d_row0_col0" class="data row0 col0" >0</td>
#       <td id="T_38f0d_row0_col1" class="data row0 col1" >1.000000</td>
#       <td id="T_38f0d_row0_col2" class="data row0 col2" >1</td>
#       <td id="T_38f0d_row0_col3" class="data row0 col3" >5.000000</td>
#       <td id="T_38f0d_row0_col4" class="data row0 col4" >0.000000</td>
#       <td id="T_38f0d_row0_col5" class="data row0 col5" >1382.000000</td>
#       <td id="T_38f0d_row0_col6" class="data row0 col6" >4.000000</td>
#       <td id="T_38f0d_row0_col7" class="data row0 col7" >15.000000</td>
#       <td id="T_38f0d_row0_col8" class="data row0 col8" >2</td>
#       <td id="T_38f0d_row0_col9" class="data row0 col9" >181.000000</td>
#       <td id="T_38f0d_row0_col10" class="data row0 col10" >1.000000</td>
#       <td id="T_38f0d_row0_col11" class="data row0 col11" >2.000000</td>
#       <td id="T_38f0d_row0_col12" class="data row0 col12" >nan</td>
#       <td id="T_38f0d_row0_col13" class="data row0 col13" >2.000000</td>
#       <td id="T_38f0d_row0_col14" class="data row0 col14" >68fd1e64</td>
#       <td id="T_38f0d_row0_col15" class="data row0 col15" >80e26c9b</td>
#       <td id="T_38f0d_row0_col16" class="data row0 col16" >fb936136</td>
#       <td id="T_38f0d_row0_col17" class="data row0 col17" >7b4723c4</td>
#       <td id="T_38f0d_row0_col18" class="data row0 col18" >25c83c98</td>
#       <td id="T_38f0d_row0_col19" class="data row0 col19" >7e0ccccf</td>
#       <td id="T_38f0d_row0_col20" class="data row0 col20" >de7995b8</td>
#       <td id="T_38f0d_row0_col21" class="data row0 col21" >1f89b562</td>
#       <td id="T_38f0d_row0_col22" class="data row0 col22" >a73ee510</td>
#       <td id="T_38f0d_row0_col23" class="data row0 col23" >a8cd5504</td>
#       <td id="T_38f0d_row0_col24" class="data row0 col24" >b2cb9c98</td>
#       <td id="T_38f0d_row0_col25" class="data row0 col25" >37c9c164</td>
#       <td id="T_38f0d_row0_col26" class="data row0 col26" >2824a5f6</td>
#       <td id="T_38f0d_row0_col27" class="data row0 col27" >1adce6ef</td>
#       <td id="T_38f0d_row0_col28" class="data row0 col28" >8ba8b39a</td>
#       <td id="T_38f0d_row0_col29" class="data row0 col29" >891b62e7</td>
#       <td id="T_38f0d_row0_col30" class="data row0 col30" >e5ba7672</td>
#       <td id="T_38f0d_row0_col31" class="data row0 col31" >f54016b9</td>
#       <td id="T_38f0d_row0_col32" class="data row0 col32" >21ddcdc9</td>
#       <td id="T_38f0d_row0_col33" class="data row0 col3
# Feature Statistics (including missing value analysis):
# <style type="text/css">
# #T_325c1_row0_col2, #T_325c1_row5_col2, #T_325c1_row6_col2, #T_325c1_row27_col2, #T_325c1_row32_col2 {
#   background-color: #440154;
#   color: #f1f1f1;
# }
# #T_325c1_row0_col4 {
#   width: 10em;
#   background: linear-gradient(90deg, salmon 100.0%, transparent 100.0%);
# }
# #T_325c1_row0_col6 {
#   width: 10em;
#   background: linear-gradient(90deg, lightblue 58.7%, transparent 58.7%);
# }
# #T_325c1_row1_col2, #T_325c1_row24_col2 {
#   background-color: #450559;
#   color: #f1f1f1;
# }
# #T_325c1_row1_col4 {
#   width: 10em;
#   background: linear-gradient(90deg, salmon 95.1%, transparent 95.1%);
# }
# #T_325c1_row1_col6, #T_325c1_row6_col6, #T_325c1_row7_col6, #T_325c1_row8_col6, #T_325c1_row9_col6, #T_325c1_row10_col6, #T_325c1_row11_col6, #T_325c1_row13_col6, #T_325c1_row14_col6, #T_325c1_row15_col6, #T_325c1_row16_col6, #T_325c1_row27_col6, #T_325c1_row37_col6, #T_325c1_row38_col6 {
#   width: 10em;
#   background: linear-gradient(90deg, lightblue 12.5%, transparent 12.5%);
# }
# #T_325c1_row2_col2 {
#   background-color: #297a8e;
#   color: #f1f1f1;
# }
# #T_325c1_row2_col4, #T_325c1_row3_col4, #T_325c1_row4_col4, #T_325c1_row5_col4 {
#   width: 10em;
#   background: linear-gradient(90deg, salmon 61.1%, transparent 61.1%);
# }
# #T_325c1_row2_col6, #T_325c1_row3_col6, #T_325c1_row4_col6, #T_325c1_row5_col6 {
#   width: 10em;
#   background: linear-gradient(90deg, lightblue 74.9%, transparent 74.9%);
# }
# #T_325c1_row3_col2, #T_325c1_row33_col2 {
#   background-color: #470d60;
#   color: #f1f1f1;
# }
# #T_325c1_row4_col2 {
#   background-color: #453581;
#   color: #f1f1f1;
# }
# #T_325c1_row6_col4, #T_325c1_row7_col4 {
#   width: 10em;
#   background: linear-gradient(90deg, salmon 56.2%, transparent 56.2%);
# }
# #T_325c1_row7_col2 {
#   background-color: #471164;
#   color: #f1f1f1;
# }
# #T_325c1_row8_col2 {
#   background-color: #2e6e8e;
#   color: #f1f1f1;
# }
# #T_325c1_row8_col4 {
#   width: 10em;
#   background: linear-gradient(90deg, salmon 30.4%, transparent 30.4%);
# }
# #T_325c1_row9_col2 {
#   background-color: #472f7d;
#   color: #f1f1f1;
# }
# #T_325c1_row9_col4 {
#   width: 10em;
#   background: linear-gradient(90deg, salmon 28.2%, transparent 28.2%);
# }
# #T_325c1_row10_col2 {
#   background-color: #481f70;
#   color: #f1f1f1;
# }
# #T_325c1_row10_col4, #T_325c1_row11_col4 {
#   width: 10em;
#   background: linear-gradient(90deg, salmon 26.1%, transparent 26.1%);
# }
# #T_325c1_row11_col2, #T_325c1_row36_col2, #T_325c1_row37_col2 {
#   background-color: #48186a;
#   color: #f1f1f1;
# }
# #T_325c1_row12_col2 {
#   background-color: #440256;
#   color: #f1f1f1;
# }
# #T_325c1_row12_col4 {
#   width: 10em;
#   background: linear-gradient(90deg, salmon 15.0%, transparent 15.0%);
# }
# #T_325c1_row12_col6 {
#   width: 10em;
#   background: linear-gradient(90deg, lightblue 94.0%, transparent 94.0%);
# }
# #T_325c1_row13_col2 {
#   background-color: #fde725;
#   color: #000000;
# }
# #T_325c1_row13_col4 {
#   width: 10em;
#   background: linear-gradient(90deg, salmon 5.0%, transparent 5.0%);
# }
# #T_325c1_row14_col2 {
#   background-color: #460b5e;
#   color: #f1f1f1;
# }
# #T_325c1_row14_col4, #T_325c1_row15_col4, #T_325c1_row16_col4 {
#   width: 10em;
#   background: linear-gradient(90deg, salmon 4.8%, transparent 4.8%);
# }
# #T_325c1_row15_col2 {
#   background-color: #2b748e;
#   color: #f1f1f1;
# }
# #T_325c1_row16_col2 {
#   background-color: #482677;
#   color: #f1f1f1;
# }
# #T_325c1_row17_col2 {
#   background-color: #1f988b;
#   color: #f1f1f1;
# }
# #T_325c1_row17_col4, #T_325c1_row18_col4, #T_325c1_row19_col4, #T_325c1_row20_col4, #T_325c1_row21_col4, #T_325c1_row22_col4 {
#   width: 10em;
#   background: linear-gradient(90deg, salmon 4.0%, transparent 4.0%);
# }
# #T_325c1_row17_col6, #T_325c1_row18_col6, #T_325c1_row19_col6, #T_325c1_row20_col6, #T_325c1_row21_col6, #T_325c1_row22_col6 {
#   width: 10em;
#   background: linear-gradient(90deg, lightblue 98.4%, transparent 98.4%);
# }
# #T_325c1_row18_col2 {
#   background-color: #a0da39;
#   color: #000000;
# }
# #T_325c1_row19_col2 {
#   background-color: #4ec36b;
#   color: #000000;
# }
# #T_325c1_row20_col2 {
#   background-color: #7fd34e;
#   color: #000000;
# }
# #T_325c1_row21_col2 {
#   background-color: #89d548;
#   color: #000000;
# }
# #T_325c1_row22_col2 {
#   background-color: #73d056;
#   color: #000000;
# }
# #T_325c1_row23_col2 {
#   background-color: #32b67a;
#   color: #f1f1f1;
# }
# #T_325c1_row23_col4, #T_325c1_row24_col4, #T_325c1_row25_col4, #T_325c1_row26_col4, #T_325c1_row27_col4, #T_325c1_row28_col4, #T_325c1_row29_col4, #T_325c1_row30_col4, #T_325c1_row31_col4, #T_325c1_row32_col4, #T_325c1_row33_col4, #T_325c1_row34_col4, #T_325c1_row35_col4, #T_325c1_row36_col4, #T_325c1_row37_col4, #T_325c1_row38_col4, #T_325c1_row39_col4 {
#   width: 10em;
# }
# #T_325c1_row23_col6, #T_325c1_row24_col6, #T_325c1_row25_col6, #T_325c1_row26_col6, #T_325c1_row28_col6, #T_325c1_row29_col6, #T_325c1_row30_col6, #T_325c1_row31_col6, #T_325c1_row32_col6, #T_325c1_row33_col6, #T_325c1_row34_col6, #T_325c1_row35_col6, #T_325c1_row36_col6, #T_325c1_row39_col6 {
#   width: 10em;
#   background: linear-gradient(90deg, lightblue 100.0%, transparent 100.0%);
# }
# #T_325c1_row25_col2 {
#   background-color: #25858e;
#   color: #f1f1f1;
# }
# #T_325c1_row26_col2 {
#   background-color: #450457;
#   color: #f1f1f1;
# }
# #T_325c1_row28_col2 {
#   background-color: #46075a;
#   color: #f1f1f1;
# }
# #T_325c1_row29_col2 {
#   background-color: #44bf70;
#   color: #f1f1f1;
# }
# #T_325c1_row30_col2 {
#   background-color: #67cc5c;
#   color: #000000;
# }
# #T_325c1_row31_col2 {
#   background-color: #38b977;
#   color: #f1f1f1;
# }
# #T_325c1_row34_col2 {
#   background-color: #460a5d;
#   color: #f1f1f1;
# }
# #T_325c1_row35_col2 {
#   background-color: #3c4f8a;
#   color: #f1f1f1;
# }
# #T_325c1_row38_col2 {
#   background-color: #375a8c;
#   color: #f1f1f1;
# }
# #T_325c1_row39_col2 {
#   background-color: #b2dd2d;
#   color: #000000;
# }
# </style>
# <table id="T_325c1">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_325c1_level0_col0" class="col_heading level0 col0" >Feature</th>
#       <th id="T_325c1_level0_col1" class="col_heading level0 col1" >Type</th>
#       <th id="T_325c1_level0_col2" class="col_heading level0 col2" >Cardinality</th>
#       <th id="T_325c1_level0_col3" class="col_heading level0 col3" >Missing Count</th>
#       <th id="T_325c1_level0_col4" class="col_heading level0 col4" >Missing Ratio(%)</th>
#       <th id="T_325c1_level0_col5" class="col_heading level0 col5" >Memory Usage(MB)</th>
#       <th id="T_325c1_level0_col6" class="col_heading level0 col6" >Memory Ratio(%)</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_325c1_level0_row0" class="row_heading level0 row0" >35</th>
#       <td id="T_325c1_row0_col0" class="data row0 col0" >C22</td>
#       <td id="T_325c1_row0_col1" class="data row0 col1" >object</td>
#       <td id="T_325c1_row0_col2" class="data row0 col2" >5</td>
#       <td id="T_325c1_row0_col3" class="data row0 col3" >815</td>
#       <td id="T_325c1_row0_col4" class="data row0 col4" >81.500000</td>
#       <td id="T_325c1_row0_col5" class="data row0 col5" >0.040000</td>
#       <td id="T_325c1_row0_col6" class="data row0 col6" >2.250000</td>
#     </tr>
#     <tr>
#       <th id="T_325c1_level0_row1" class="row_heading level0 row1" >12</th>
#       <td id="T_325c1_row1_col0" class="data row1 col0" >I12</td>
#       <td id="T_325c1_row1_col1" class="data row1 col1" >float64</td>
#       <td id="T_325c1_row1_col2" class="data row1 col2" >13</td>
#       <td id="T_325c1_row1_col3" class="data row1 col3" >775</td>
#       <td id="T_325c1_row1_col4" class="data row1 col4" >77.500000</td>
#       <td id="T_325c1_row1_col5" class="data row1 col5" >0.010000</td>
#       <td id="T_325c1_row1_col6" class="data row1 col6" >0.480000</td>
#     </tr>
#     <tr>
#       <th id="T_325c1_level0_row2" class="row_heading level0 row2" >39</th>
#       <td id="T_325c1_row2_col0" class="data row2 col0" >C26</td>
#       <td id="T_325c1_row2_col1" class="data row2 col1" >object</td>
#       <td id="T_325c1_row2_col2" class="data row2 col2" >321</td>
#       <td id="T_325c1_row2_col3" class="data row2 col3" >498</td>
#       <td id="T_325c1_row2_col4" class="data row2 col4" >49.800000</td>
#       <td id="T_325c1_row2_col5" class="d
